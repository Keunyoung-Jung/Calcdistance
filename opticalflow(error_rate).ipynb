# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import math
import pypdr

#-------------------------에러값을 계산하기 위한 함수--------------------
def error_value(filename,dist) :
    filename_array = filename.split('_')
    real_dist = int(filename_array[1])
    #파일 이름에 있는 실험거리를 가져옴
    error_dist = ((abs(real_dist - dist))/real_dist)*100
    #실험거리를 측정된거리와의 차이를 구해서 오차율을 구함 
    return error_dist
    

#-------------------------거리측정 결과그래프를 그리기 위한 함수--------------------
def result_line(array1,array2,array3,array4) :
    style = '-'
    widths = 1
    xpoints1 = np.arange(0,len(array1),1)
    ypoints1 = array1
    xpoints2 = np.arange(0,len(array1),1)
    ypoints2 = array2
    xpoints3 = np.arange(0,len(array1),1)
    ypoints3 = array3
    xpoints4 = np.arange(0,len(array1),1)
    ypoints4 = array4
    plt.figure(figsize=(10,4))
    plt.plot(xpoints1,ypoints1,linestyle=style,color='mediumseagreen',linewidth=widths,label='median')
    plt.plot(xpoints2,ypoints2,linestyle=style,color='blue',linewidth=widths,label='average')
    plt.plot(xpoints3,ypoints3,linestyle=style,color='red',linewidth=widths,label='maxhist')
    plt.plot(xpoints4,ypoints4,linestyle=style,color='orange',linewidth=widths,label='mix')
    plt.title("distance")
    plt.xlabel("video_number")
    plt.ylabel("distance")
    plt.legend(loc='upper left')
    plt.show("lines")

#-------------------------오차율 그래프를 그리기 위한 함수--------------------
def error_line(array1,array2,array3,array4) :
    style = '-'
    widths = 1
    xpoints1 = np.arange(0,len(array1),1)
    ypoints1 = array1
    xpoints2 = np.arange(0,len(array1),1)
    ypoints2 = array2
    xpoints3 = np.arange(0,len(array1),1)
    ypoints3 = array3
    xpoints4 = np.arange(0,len(array1),1)
    ypoints4 = array4
    plt.figure(figsize=(10,4))
    plt.plot(xpoints1,ypoints1,linestyle=style,color='mediumseagreen',linewidth=widths,label='median')
    plt.plot(xpoints2,ypoints2,linestyle=style,color='blue',linewidth=widths,label='average')
    plt.plot(xpoints3,ypoints3,linestyle=style,color='red',linewidth=widths,label='maxhist')
    plt.plot(xpoints4,ypoints4,linestyle=style,color='orange',linewidth=widths,label='mix')
    plt.title("error")
    plt.xlabel("video_number")
    plt.ylabel("error(rate)")
    plt.legend(loc='upper left')
    plt.show("lines")


#-------------------------CDF(오차누적그래프)를 그리기 위한 함수--------------------
def error_accurmulate_line(array1,array2,array3,array4) :
    widths = 1
    ypoints1 = np.arange(0,0.99,(1/len(array1))) 
    xpoints1 = array1
    ypoints2 = np.arange(0,0.99,(1/len(array1)))
    xpoints2 = array2
    ypoints3 = np.arange(0,0.99,(1/len(array1)))
    xpoints3 = array3
    ypoints4 = np.arange(0,0.99,(1/len(array1)))
    xpoints4 = array4
    plt.figure(figsize=(10,4))
    plt.plot(xpoints1,ypoints1,linestyle='-',color='mediumseagreen',linewidth=widths,label='median')
    plt.plot(xpoints2,ypoints2,linestyle='-.',color='blue',linewidth=widths,label='average')
    plt.plot(xpoints3,ypoints3,linestyle='--',color='red',linewidth=widths,label='maxhist')
    #plt.plot(xpoints4,ypoints4,linestyle='-',color='orange',linewidth=widths,label='mix')
    plt.title("error_accurmurate")
    plt.ylabel("video_number(cdf)")
    plt.xlabel("error(rate)")
    plt.ylim(0,1)
    plt.legend(loc='upper left')
    plt.show("lines")


    
def mid(a, b):
    return (a+b)/2

def getMedianTupleOfOneColumn(tupleArray, col):    #특정 열의 값으로 중앙값 찾기 (col: 0~)
    size = len(tupleArray)
    if (size == 0): return (0,0,0)

    sortedArray = sorted(tupleArray, key=lambda elem: elem[col])

    medianTuple = sortedArray[0]
    if (size % 2 == 0):
        a = int(size / 2)
        b = a - 1
        medianTuple = (mid(sortedArray[a][0], sortedArray[b][0]),\
                mid(sortedArray[a][1], sortedArray[b][1]),\
                mid(sortedArray[a][2], sortedArray[b][2]))
    else:
        medianTuple = sortedArray[size / 2]

    return medianTuple

def runPdr(pdr, txtLine):
    if len(txtLine) == 0: return

    row = txtLine.split()
    time = float(row[0]) * 1000          # 센서 측정시간 (millis)
    acc = [float(i) for i in row[1:4]]   # 가속도센서
    mag = [float(i) for i in row[4:7]]   # 지자기센서
    gyro = [float(i) for i in row[7:10]] # 자이로센서

    # PDR 계산
    pdr.calculate(acc, gyro, mag, time, 0)
    return pdr.getStepCount()

def line(array1,array2,array3):    #그래프를 뽑기위한 함수
    style = '-'
    colors = 'mediumseagreen'
    widths = 1
    xpoints1 = np.arange(0,len(array1),1)
    ypoints1 = array1
    xpoints2 = np.arange(0,len(array1),1)
    ypoints2 = array2
    xpoints3 = np.arange(0,len(array1),1)
    ypoints3 = array3
    plt.figure(figsize=(3,4))
    #plt.ylim(0, 10)
    plt.plot(xpoints1,ypoints1,linestyle=style,color=colors,linewidth=widths,label='median result')
    plt.plot(xpoints2,ypoints2,linestyle=style,color='blue',linewidth=widths,label='average result')
    plt.plot(xpoints3,ypoints3,linestyle=style,color='red',linewidth=widths,label='maxhist result')
    plt.title("distance")
    plt.xlabel("frame")
    plt.ylabel("value")
    plt.legend(loc='upper left')
    plt.show("lines")
    
def showMotionVectors(diffpoint,diffpoint2, calcDist1=None, calcDist2=None, calcDist3=None , bins =None):
    plt.grid(color='k', linestyle='-', linewidth=0.1)
    #plt.xlim(-.08, .08)
    #plt.ylim(-1, 30)
    plt.xlabel("cm")
    plt.ylabel("y")
    plt.scatter(diffpoint[:],np.zeros_like(diffpoint),color='mediumseagreen', label='features')
    plt.hist(diffpoint2[:],bins=bins,color='yellowgreen',histtype='stepfilled')
    if calcDist1 is not None :
        plt.scatter(calcDist1, 0,color='orange' ,label='median result')
    if calcDist2 is not None :
        plt.scatter(calcDist2, 0,color='blue' ,label='average result')
    if calcDist3 is not None :
        plt.scatter(calcDist3, 0,color='red' ,label='max hist result')
        
    plt.legend(loc='upper left')
    plt.show()
    
def distcalc(Filename,startlabel=None,finishlabel=None) :
    termination = (cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT,10,0.03)
    feature_params = dict(maxCorners=200, qualityLevel = 0.01,minDistance =20, blockSize = 3)
    lk_params = dict(winSize=(20,20),maxLevel = 5,criteria=termination)
    FilePath = 'sensor video3/'+Filename+'.mp4'
    realvalue = 3.7325
    xyarray=[]
    xarray=[]
    yarray=[] 
    cap = cv2.VideoCapture(FilePath)
    count = 0
    disttotal = 0
    disttotal_a = 0
    disttotal_h = 0
    w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) 
    h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    fourcc = cv2.VideoWriter_fourcc(*'MJPG')
    #out = cv2.VideoWriter('video_out.avi', fourcc, fps, (w, h))
    _, prev = cap.read() 
    prev = prev[0:480, 0:250]
    prevgray = cv2.cvtColor(prev, cv2.COLOR_BGR2GRAY) 
    distarray_median = []
    distarray_average = []
    distarray_maxhist = []
    distarray_mix = []
    framebuffer = []
    
    sensorFilePath = 'sensor video3/'+Filename+'.txt'
    sensorFile = open(sensorFilePath)
    pdr = pypdr.Pdr()
    stepCount = 0
    stepCount_a = 0
    stepCount_h = 0
    stepLength = 0
    stepLength_a = 0
    stepLength_h = 0

    #for count in range(n_frames-2) :
    while True :
        ret , frame = cap.read()
        if not ret :
            break
        frame = frame[0:480, 0:250]
        #frame = cv2.resize(frame, None, fx=scaling_factor, fy=scaling_factor, interpolation=cv2.INTER_AREA)
        #ROI = cv2.rectangle(frame,(0,0),(320,480),(0,0,255),2)
        framegray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
        view = frame.copy()
        
        framebuffer.append(frame)
        
        mask = np.zeros_like(prevgray)
        mask0 = np.zeros_like(prev)
        mask[:] = 255
        feature_points = cv2.goodFeaturesToTrack(prevgray,mask=mask,**feature_params)
        corners = np.int0(feature_points)
        for i in corners : 
            x, y = i.ravel()
            cv2.circle(view,(x,y),1,255,-1)
            xyval = (x,y)
            xyarray.append(xyval)
            xarray.append(x)
            yarray.append(y)
            
        #print(xyarray)
        xyarray = []
        
        #print(xarray)
        
        flow_point, st, err = cv2.calcOpticalFlowPyrLK(prevgray,framegray,feature_points,None,**lk_params)
        #flow_point_rev, st, err = cv2.calcOpticalFlowPyrLK(framegray,prevgray,flow_point,None,**lk_params)
        #diffpoint = abs(feature_points - flow_point_rev).reshape(-1,2).max(-1)
        #goodpoint = diffpoint < 1
        
        #assert feature_points.shape == goodpoint.shape
        corners0 = np.int0(flow_point)

        idx = np.where(st ==1)[0]
        good_feature_points = feature_points[idx]
        good_flow_point = flow_point[idx]
        #good_flow_point[:,:,1] = good_feature_points[:,:,1]
        #good_feature_points[:,:,1] = good_flow_point[:,:,1]
        #y값을 같게 해서 x값으로만 계산
        distarray=[]
        distarray2=[]
        for i,(new,old) in enumerate(zip(good_flow_point,good_feature_points)):
            a,b = new.ravel()
            c,d = old.ravel()
            dist = math.sqrt((a-c)*(a-c)+(b-d)*(b-d))
            angle = math.atan((b-d)/(a-c+1e-15))
            rad = math.atan2((b-d),(a-c))
            #print(angle)
            view = cv2.circle(view,(a,b),3,(0,255,0),-1)
            if dist < 25 :
                if c < a and -0.52359877566 < angle < 0.52359877566 :
                    mask0 = cv2.line(mask0,(a,b),(c,d),(0,255,0),1)
                    distarray.append((a-c)/realvalue)
                    
        hist , bins =  np.histogram(distarray)
        #print(distarray)
        #print(hist)
        bins_mk = []
        bins_mk2 = []
        for x in range(0,9) :
            bins_mk.append([bins[x],bins[x+1]])
        #print(bins_mk)
        for x in range(0,9) :
            if hist[x] == max(hist) :
                bins_mk2.append(bins_mk[x])
                    
        #print(max(max(bins_mk2)))
        for x in range(0,len(distarray)) :
            if bins_mk2 != [] :
                if min(min(bins_mk2)) <= distarray[x] <= max(max(bins_mk2)) :
                    distarray2.append(distarray[x])

        #print('-------------------------'+str(count)+'------------------------')
        img = cv2.add(view,mask0)  

        distmedian = np.median(distarray)
        distaverage = np.mean(distarray)
        distmaxhist = np.median(distarray2)
        # ***** Yaw 관련해서 추가한 부분 ***** #
        txtLine = sensorFile.readline()
        currentStepCount = stepCount

        if txtLine != None:
            currentStepCount = runPdr(pdr, txtLine)

            timesec = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000
            while (len(txtLine) > 0 and float(txtLine[0]) < timesec):
                txtLine = sensorFile.readline()
                currentStepCount = runPdr(pdr, txtLine)

        yaw = pdr.getYaw()

#         distmedian = distmedian * math.cos(yaw)
        # ***** ********************** ***** #  

        currentStepCount_a = currentStepCount
        currentStepCount_h = currentStepCount
        StepCount_a = stepCount
        StepCount_h = stepCount
        
        if distmedian > 1 :
            stepLength += distmedian * math.cos(yaw)
            if currentStepCount != None and stepCount < currentStepCount:
                stepCount = currentStepCount
                disttotal += stepLength
                stepLength = 0

        if distaverage > 1 :
            stepLength_a += distaverage * math.cos(yaw)
            if currentStepCount_a != None and stepCount_a < currentStepCount_a:
                stepCount_a = currentStepCount_a
                disttotal_a += stepLength_a
                stepLength_a = 0
        
        if distmaxhist > 1 :
            stepLength_h += distmedian * math.cos(yaw)
            if currentStepCount_h != None and stepCount_h < currentStepCount_h:
                stepCount_h = currentStepCount_h
                disttotal_h += stepLength_h
                stepLength_h = 0   
                
        distarray_median.append(disttotal/100)
        distarray_average.append(disttotal_a/100)
        distarray_maxhist.append(disttotal_h/100)   
        
        
        #showMotionVectors(distarray,distarray,distmedian,distaverage,distmaxhist,bins)
        
        #print(Filename,'median_','--frame_num :' ,count ,'value(cm) :' ,distmedian , 'distance(m) : ',disttotal/100)
        #print(Filename,'average_','--frame_num :' ,count ,'value(cm) :' ,distaverage , 'distance(m) : ',disttotal_a/100)
        #print(Filename,'maxhist_','--frame_num :' ,count ,'value(cm) :' ,distmaxhist , 'distance(m) : ',disttotal_h/100)
        distance_print = "dist: %.2f m"%(disttotal/100)
        #print(distarray)
        cv2.putText(img, distance_print,(0,50),cv2.FONT_HERSHEY_SIMPLEX,1,(255,0,0))
        
        
        prevgray = framegray
#         cv2.imshow('orginal',img)
#         cv2.imwrite('img/'+Filename+'/'+Filename+'-frame'+str(count)+'.jpg',img)
       
        k = cv2.waitKey(30)
        if k == 27:
            break
        count += 1
    
    disttotal += stepLength
    disttotal_a += stepLength_a
    disttotal_h += stepLength_h
    
    disterror = error_value(Filename,disttotal/100)
    disterror_a = error_value(Filename,disttotal_a/100)
    disterror_h = error_value(Filename,disttotal_h/100)
    
    disttotal_mix = (disttotal+disttotal_a)/2
    disterror_mix = error_value(Filename,disttotal_mix/100)
    
    print('median error : %.2f'%disterror+'% /','average error : %.2f'%disterror_a+'% /','maxhist error : %.2f'%disterror_h+'% /' ,'mix error : %.2f'%disterror_mix+'%')
    distarray_median.append(disttotal/100)
    distarray_average.append(disttotal_a/100)
    distarray_maxhist.append(disttotal_h/100)
    distarray_mix.append(disttotal_mix/100)
    
    #line(distarray_median,distarray_average,distarray_maxhist)
    print('----------------------------------------------------------------------------------------')
    print(Filename,'median_','distance(m) : ',disttotal/100)
    print(Filename,'average_','distance(m) : ',disttotal_a/100)
    print(Filename,'maxhist_','distance(m) : ',disttotal_h/100)
    print(Filename,'mix_','distance(m) : ',disttotal_mix/100)
    print('----------------------------------------------------------------------------------------')
    cap.release()
    sensorFile.close()
    cv2.destroyAllWindows()
    
    return disttotal/100 , disttotal_a/100 , disttotal_h/100 , disttotal_mix/100 , disterror , disterror_a , disterror_h , disterror_mix

# Result

dist_loca = ['ss','yg','gh','dr']
#상상관지하1층,연구동2층,공학관3층,일반아스팔트도로
dist_value = ['3','10']
#3m , 10m 실험
dist_mode = ['normal','fast','slow','stop']
#보통 , 빠른 , 느린 , 멈춤 4가지실험
dist_number = ['1','2','3']
#총3번의 실험 진행

#-------------------------------------그래프와 결과 출력--------------------------------

error_acc_median_t = []
error_acc_average_t = []
error_acc_maxhist_t = []
error_acc_mixar_t = []

error_acc_median_t.append(0)
error_acc_average_t.append(0)
error_acc_maxhist_t.append(0)
error_acc_mixar_t.append(0)

for a in dist_value :
    
    error_acc_median_d = []
    error_acc_average_d = []
    error_acc_maxhist_d = []
    error_acc_mixar_d = []
    
    error_acc_median_d.append(0)
    error_acc_average_d.append(0)
    error_acc_maxhist_d.append(0)
    error_acc_mixar_d.append(0)
    
    for b in dist_loca :
        
        disttotal_array_median = []
        disttotal_array_average = []
        disttotal_array_maxhist = []
        disttotal_array_mix = []

        error_array_median = []
        error_array_average = []
        error_array_maxhist = []
        error_array_mix = []
        
        error_acc_median = []
        error_acc_average = []
        error_acc_maxhist = []
        error_acc_mixar = []
        
        error_acc_median.append(0)
        error_acc_average.append(0)
        error_acc_maxhist.append(0)
        error_acc_mixar.append(0)
        
        error_acc_m = 0
        error_acc_a = 0
        error_acc_h = 0
        error_acc_mix = 0
        
        for j in dist_mode :
            for k in dist_number :
                # ------------------------yg_fast의 2,3번 오류처리 부분 --------------------------------------
                if j == 'fast' and b == 'yg' and a == '3' :
                    if k == '2' or k == '3' :
                        median , average , maxhist ,mix = 3, 3 ,3 , 3
                        error_m , error_a , error_h ,error_mix = 0, 0 ,0 ,0
                    else :
                        median , average , maxhist ,mix,error_m , error_a , error_h ,error_mix = distcalc(b+'_'+a+'_'+j+'_'+k)
                # --------------------------------------------------------------------------------------------
                else :
                    median , average , maxhist,mix ,error_m , error_a , error_h ,error_mix = distcalc(b+'_'+a+'_'+j+'_'+k)
                    
                error_acc_m = error_m
                error_acc_a = error_a
                error_acc_h = error_h 
                error_acc_mix = error_mix 

                disttotal_array_median.append(median)
                disttotal_array_average.append(average)
                disttotal_array_maxhist.append(maxhist)
                disttotal_array_mix.append(mix)
                
                error_array_median.append(error_m)
                error_array_average.append(error_a)
                error_array_maxhist.append(error_h)
                error_array_mix.append(error_mix)
                
                error_acc_median.append(error_acc_m)
                error_acc_average.append(error_acc_a)
                error_acc_maxhist.append(error_acc_h)
                error_acc_mixar.append(error_acc_mix)
                
                error_acc_median_d.append(error_acc_m)
                error_acc_average_d.append(error_acc_a)
                error_acc_maxhist_d.append(error_acc_h)
                error_acc_mixar_d.append(error_acc_mix)
                
                error_acc_median_t.append(error_acc_m)
                error_acc_average_t.append(error_acc_a)
                error_acc_maxhist_t.append(error_acc_h)
                error_acc_mixar_t.append(error_acc_mix)
                
        error_acc_median.sort()
        error_acc_average.sort()
        error_acc_maxhist.sort()
        error_acc_mixar.sort()
                
        result_line(disttotal_array_median,disttotal_array_average,disttotal_array_maxhist,disttotal_array_mix)
        error_line(error_array_median,error_array_average,error_array_maxhist,error_array_mix)
        error_accurmulate_line(error_acc_median,error_acc_average,error_acc_maxhist,error_acc_mixar)
        
    error_acc_median_d.sort()
    error_acc_average_d.sort()
    error_acc_maxhist_d.sort()
    error_acc_mixar_d.sort()

    error_accurmulate_line(error_acc_median_d,error_acc_average_d,error_acc_maxhist_d,error_acc_mixar_d)
    
error_acc_median_t.sort()
error_acc_average_t.sort()
error_acc_maxhist_t.sort()
error_acc_mixar_t.sort()    

error_accurmulate_line(error_acc_median_t,error_acc_average_t,error_acc_maxhist_t,error_acc_mixar_t)

'''
median , average , maxhist = distcalc('ss_3_normal_1')
median , average , maxhist = distcalc('ss_3_normal_2')
median , average , maxhist = distcalc('ss_3_normal_3')
median , average , maxhist = distcalc('ss_3_fast_1')
median , average , maxhist = distcalc('ss_3_fast_2')
median , average , maxhist = distcalc('ss_3_fast_3')
median , average , maxhist = distcalc('ss_3_slow_1')
median , average , maxhist = distcalc('ss_3_slow_2')
median , average , maxhist = distcalc('ss_3_slow_3')
median , average , maxhist = distcalc('ss_3_stop_1')
median , average , maxhist = distcalc('ss_3_stop_2')
median , average , maxhist = distcalc('ss_3_stop_3')
median , average , maxhist = distcalc('ss_10_normal_1')
median , average , maxhist = distcalc('ss_10_normal_2')
median , average , maxhist = distcalc('ss_10_normal_3')
median , average , maxhist = distcalc('ss_10_fast_1')
median , average , maxhist = distcalc('ss_10_fast_2')
median , average , maxhist = distcalc('ss_10_fast_3')
median , average , maxhist = distcalc('ss_10_slow_1')
median , average , maxhist = distcalc('ss_10_slow_2')
median , average , maxhist = distcalc('ss_10_slow_3')
median , average , maxhist = distcalc('ss_10_stop_1')
median , average , maxhist = distcalc('ss_10_stop_2')
median , average , maxhist = distcalc('ss_10_stop_3')
median , average , maxhist = distcalc('yg_3_normal_1')
median , average , maxhist = distcalc('yg_3_normal_2')
median , average , maxhist = distcalc('yg_3_normal_3')
median , average , maxhist = distcalc('yg_3_fast_1')
#median , average , maxhist = distcalc('yg_3_fast_2')
#median , average , maxhist = distcalc('yg_3_fast_3')
median , average , maxhist = distcalc('yg_3_slow_1')
median , average , maxhist = distcalc('yg_3_slow_2')
median , average , maxhist = distcalc('yg_3_slow_3')
median , average , maxhist = distcalc('yg_3_stop_1')
median , average , maxhist = distcalc('yg_3_stop_2')
median , average , maxhist = distcalc('yg_3_stop_3')
median , average , maxhist = distcalc('yg_10_normal_1')
median , average , maxhist = distcalc('yg_10_normal_2')
median , average , maxhist = distcalc('yg_10_normal_3')
median , average , maxhist = distcalc('yg_10_fast_1')
median , average , maxhist = distcalc('yg_10_fast_2')
median , average , maxhist = distcalc('yg_10_fast_3')
median , average , maxhist = distcalc('yg_10_slow_1')
median , average , maxhist = distcalc('yg_10_slow_2')
median , average , maxhist = distcalc('yg_10_slow_3')
median , average , maxhist = distcalc('yg_10_stop_1')
median , average , maxhist = distcalc('yg_10_stop_2')
median , average , maxhist = distcalc('yg_10_stop_3')
'''
# Out:
# median error : 6.33% / average error : 5.25% / maxhist error : 3.95% / mix error : 5.79%
# ----------------------------------------------------------------------------------------
# ss_3_normal_1 median_ distance(m) :  3.19002624918
# ss_3_normal_1 average_ distance(m) :  3.15763961921
# ss_3_normal_1 maxhist_ distance(m) :  3.11849819396
# ss_3_normal_1 mix_ distance(m) :  3.17383293419
# ----------------------------------------------------------------------------------------
# median error : 1.95% / average error : 1.49% / maxhist error : 2.99% / mix error : 1.72%
# ----------------------------------------------------------------------------------------
# ss_3_normal_2 median_ distance(m) :  2.94151120245
# ss_3_normal_2 average_ distance(m) :  2.95527628776
# ss_3_normal_2 maxhist_ distance(m) :  2.91039835061
# ss_3_normal_2 mix_ distance(m) :  2.94839374511
# ----------------------------------------------------------------------------------------
# median error : 5.49% / average error : 4.24% / maxhist error : 0.34% / mix error : 4.87%
# ----------------------------------------------------------------------------------------
# ss_3_normal_3 median_ distance(m) :  3.1648163763
# ss_3_normal_3 average_ distance(m) :  3.12734963166
# ss_3_normal_3 maxhist_ distance(m) :  3.01011743443
# ss_3_normal_3 mix_ distance(m) :  3.14608300398
# ----------------------------------------------------------------------------------------
# median error : 3.73% / average error : 4.27% / maxhist error : 2.29% / mix error : 4.00%
# ----------------------------------------------------------------------------------------
# ss_3_fast_1 median_ distance(m) :  3.11202838915
# ss_3_fast_1 average_ distance(m) :  3.12816688498
# ss_3_fast_1 maxhist_ distance(m) :  3.06878178505
# ss_3_fast_1 mix_ distance(m) :  3.12009763707
# ----------------------------------------------------------------------------------------
# median error : 2.09% / average error : 2.80% / maxhist error : 4.59% / mix error : 2.44%
# ----------------------------------------------------------------------------------------
# ss_3_fast_2 median_ distance(m) :  2.93722962428
# ss_3_fast_2 average_ distance(m) :  2.91613823115
# ss_3_fast_2 maxhist_ distance(m) :  2.86234037015
# ss_3_fast_2 mix_ distance(m) :  2.92668392772
# ----------------------------------------------------------------------------------------
# median error : 5.28% / average error : 4.13% / maxhist error : 2.27% / mix error : 4.70%
# ----------------------------------------------------------------------------------------
# ss_3_fast_3 median_ distance(m) :  3.15839337968
# ss_3_fast_3 average_ distance(m) :  3.12387315954
# ss_3_fast_3 maxhist_ distance(m) :  3.06803609302
# ss_3_fast_3 mix_ distance(m) :  3.14113326961
# ----------------------------------------------------------------------------------------
# median error : 1.12% / average error : 0.46% / maxhist error : 0.19% / mix error : 0.79%
# ----------------------------------------------------------------------------------------
# ss_3_slow_1 median_ distance(m) :  3.03362910625
# ss_3_slow_1 average_ distance(m) :  3.01380655558
# ss_3_slow_1 maxhist_ distance(m) :  2.99432437062
# ss_3_slow_1 mix_ distance(m) :  3.02371783092
# ----------------------------------------------------------------------------------------
# median error : 1.44% / average error : 2.62% / maxhist error : 1.76% / mix error : 2.03%
# ----------------------------------------------------------------------------------------
# ss_3_slow_2 median_ distance(m) :  3.0432462203
# ss_3_slow_2 average_ distance(m) :  3.07848482499
# ss_3_slow_2 maxhist_ distance(m) :  3.05287900562
# ss_3_slow_2 mix_ distance(m) :  3.06086552264
# ----------------------------------------------------------------------------------------
# median error : 3.62% / average error : 2.49% / maxhist error : 4.51% / mix error : 3.06%
# ----------------------------------------------------------------------------------------
# ss_3_slow_3 median_ distance(m) :  2.89135681561
# ss_3_slow_3 average_ distance(m) :  2.92529438589
# ss_3_slow_3 maxhist_ distance(m) :  2.86467396783
# ss_3_slow_3 mix_ distance(m) :  2.90832560075
# ----------------------------------------------------------------------------------------
# median error : 0.08% / average error : 0.48% / maxhist error : 1.35% / mix error : 0.28%
# ----------------------------------------------------------------------------------------
# ss_3_stop_1 median_ distance(m) :  2.99762547839
# ss_3_stop_1 average_ distance(m) :  2.98563798956
# ss_3_stop_1 maxhist_ distance(m) :  2.9595442265
# ss_3_stop_1 mix_ distance(m) :  2.99163173398
# ----------------------------------------------------------------------------------------
# median error : 2.53% / average error : 2.99% / maxhist error : 2.43% / mix error : 2.76%
# ----------------------------------------------------------------------------------------
# ss_3_stop_2 median_ distance(m) :  2.92414625579
# ss_3_stop_2 average_ distance(m) :  2.91038900318
# ss_3_stop_2 maxhist_ distance(m) :  2.92714186224
# ss_3_stop_2 mix_ distance(m) :  2.91726762948
# ----------------------------------------------------------------------------------------
# median error : 6.66% / average error : 6.74% / maxhist error : 5.47% / mix error : 6.70%
# ----------------------------------------------------------------------------------------
# ss_3_stop_3 median_ distance(m) :  2.80018561536
# ss_3_stop_3 average_ distance(m) :  2.79786283546
# ss_3_stop_3 maxhist_ distance(m) :  2.83582654676
# ss_3_stop_3 mix_ distance(m) :  2.79902422541
# ----------------------------------------------------------------------------------------
# median error : 1.73% / average error : 1.25% / maxhist error : 2.27% / mix error : 1.49%
# ----------------------------------------------------------------------------------------
# yg_3_normal_1 median_ distance(m) :  2.94795753019
# yg_3_normal_1 average_ distance(m) :  2.96260218773
# yg_3_normal_1 maxhist_ distance(m) :  2.93204242081
# yg_3_normal_1 mix_ distance(m) :  2.95527985896
# ----------------------------------------------------------------------------------------
# median error : 1.10% / average error : 0.87% / maxhist error : 4.79% / mix error : 0.98%
# ----------------------------------------------------------------------------------------
# yg_3_normal_2 median_ distance(m) :  2.96698697954
# yg_3_normal_2 average_ distance(m) :  2.97401873543
# yg_3_normal_2 maxhist_ distance(m) :  2.85627964509
# yg_3_normal_2 mix_ distance(m) :  2.97050285749
# ----------------------------------------------------------------------------------------
# median error : 1.82% / average error : 1.10% / maxhist error : 4.22% / mix error : 1.46%
# ----------------------------------------------------------------------------------------
# yg_3_normal_3 median_ distance(m) :  2.94535977599
# yg_3_normal_3 average_ distance(m) :  2.96702247806
# yg_3_normal_3 maxhist_ distance(m) :  2.87347819188
# yg_3_normal_3 mix_ distance(m) :  2.95619112702
# ----------------------------------------------------------------------------------------
# median error : 1.09% / average error : 0.39% / maxhist error : 0.24% / mix error : 0.74%
# ----------------------------------------------------------------------------------------
# yg_3_fast_1 median_ distance(m) :  3.03260827418
# yg_3_fast_1 average_ distance(m) :  3.01158841415
# yg_3_fast_1 maxhist_ distance(m) :  3.00707370106
# yg_3_fast_1 mix_ distance(m) :  3.02209834417
# ----------------------------------------------------------------------------------------
# median error : 2.30% / average error : 0.49% / maxhist error : 2.01% / mix error : 1.40%
# ----------------------------------------------------------------------------------------
# yg_3_slow_1 median_ distance(m) :  2.93095658372
# yg_3_slow_1 average_ distance(m) :  2.98515440024
# yg_3_slow_1 maxhist_ distance(m) :  2.93972102926
# yg_3_slow_1 mix_ distance(m) :  2.95805549198
# ----------------------------------------------------------------------------------------
# median error : 8.28% / average error : 6.35% / maxhist error : 11.91% / mix error : 7.31%
# ----------------------------------------------------------------------------------------
# yg_3_slow_2 median_ distance(m) :  2.75166344436
# yg_3_slow_2 average_ distance(m) :  2.80944708785
# yg_3_slow_2 maxhist_ distance(m) :  2.64272597873
# yg_3_slow_2 mix_ distance(m) :  2.7805552661
# ----------------------------------------------------------------------------------------
# median error : 0.98% / average error : 3.12% / maxhist error : 0.25% / mix error : 2.05%
# ----------------------------------------------------------------------------------------
# yg_3_slow_3 median_ distance(m) :  3.02930532617
# yg_3_slow_3 average_ distance(m) :  3.09365123605
# yg_3_slow_3 maxhist_ distance(m) :  2.99247228255
# yg_3_slow_3 mix_ distance(m) :  3.06147828111
# ----------------------------------------------------------------------------------------
# median error : 3.33% / average error : 6.18% / maxhist error : 0.89% / mix error : 4.76%
# ----------------------------------------------------------------------------------------
# yg_3_stop_1 median_ distance(m) :  3.10002182305
# yg_3_stop_1 average_ distance(m) :  3.18554689058
# yg_3_stop_1 maxhist_ distance(m) :  2.97325571
# yg_3_stop_1 mix_ distance(m) :  3.14278435682
# ----------------------------------------------------------------------------------------
# median error : 0.37% / average error : 2.40% / maxhist error : 3.98% / mix error : 1.01%
# ----------------------------------------------------------------------------------------
# yg_3_stop_2 median_ distance(m) :  2.98876114416
# yg_3_stop_2 average_ distance(m) :  3.07198825031
# yg_3_stop_2 maxhist_ distance(m) :  2.88069235188
# yg_3_stop_2 mix_ distance(m) :  3.03037469723
# ----------------------------------------------------------------------------------------
# median error : 1.51% / average error : 3.19% / maxhist error : 6.46% / mix error : 0.84%
# ----------------------------------------------------------------------------------------
# yg_3_stop_3 median_ distance(m) :  2.95473519144
# yg_3_stop_3 average_ distance(m) :  3.09567261729
# yg_3_stop_3 maxhist_ distance(m) :  2.80628090933
# yg_3_stop_3 mix_ distance(m) :  3.02520390437
# ----------------------------------------------------------------------------------------
# median error : 0.04% / average error : 0.04% / maxhist error : 0.04% / mix error : 0.00%
# ----------------------------------------------------------------------------------------
# gh_3_normal_1 median_ distance(m) :  2.99886135375
# gh_3_normal_1 average_ distance(m) :  3.001326246
# gh_3_normal_1 maxhist_ distance(m) :  2.99886135375
# gh_3_normal_1 mix_ distance(m) :  3.00009379987
# ----------------------------------------------------------------------------------------
# median error : 5.69% / average error : 5.70% / maxhist error : 5.17% / mix error : 5.70%
# ----------------------------------------------------------------------------------------
# gh_3_normal_2 median_ distance(m) :  2.82921050185
# gh_3_normal_2 average_ distance(m) :  2.82894049201
# gh_3_normal_2 maxhist_ distance(m) :  2.84489213328
# gh_3_normal_2 mix_ distance(m) :  2.82907549693
# ----------------------------------------------------------------------------------------
# median error : 1.02% / average error : 1.62% / maxhist error : 0.40% / mix error : 1.32%
# ----------------------------------------------------------------------------------------
# gh_3_normal_3 median_ distance(m) :  2.96933267434
# gh_3_normal_3 average_ distance(m) :  2.95135071288
# gh_3_normal_3 maxhist_ distance(m) :  2.98813475617
# gh_3_normal_3 mix_ distance(m) :  2.96034169361
# ----------------------------------------------------------------------------------------
# median error : 1.09% / average error : 1.06% / maxhist error : 1.71% / mix error : 1.07%
# ----------------------------------------------------------------------------------------
# gh_3_fast_1 median_ distance(m) :  3.03255597826
# gh_3_fast_1 average_ distance(m) :  3.03180766154
# gh_3_fast_1 maxhist_ distance(m) :  3.05120957976
# gh_3_fast_1 mix_ distance(m) :  3.0321818199
# ----------------------------------------------------------------------------------------
# median error : 1.22% / average error : 1.19% / maxhist error : 1.22% / mix error : 1.21%
# ----------------------------------------------------------------------------------------
# gh_3_fast_2 median_ distance(m) :  3.03671273021
# gh_3_fast_2 average_ distance(m) :  3.03571242324
# gh_3_fast_2 maxhist_ distance(m) :  3.03671273021
# gh_3_fast_2 mix_ distance(m) :  3.03621257673
# ----------------------------------------------------------------------------------------
# median error : 5.48% / average error : 5.08% / maxhist error : 5.52% / mix error : 5.28%
# ----------------------------------------------------------------------------------------
# gh_3_fast_3 median_ distance(m) :  2.83562281159
# gh_3_fast_3 average_ distance(m) :  2.84751451214
# gh_3_fast_3 maxhist_ distance(m) :  2.83444617744
# gh_3_fast_3 mix_ distance(m) :  2.84156866186
# ----------------------------------------------------------------------------------------
# median error : 4.77% / average error : 5.20% / maxhist error : 5.29% / mix error : 4.99%
# ----------------------------------------------------------------------------------------
# gh_3_slow_1 median_ distance(m) :  2.85688138346
# gh_3_slow_1 average_ distance(m) :  2.84400019961
# gh_3_slow_1 maxhist_ distance(m) :  2.84137599655
# gh_3_slow_1 mix_ distance(m) :  2.85044079154
# ----------------------------------------------------------------------------------------
# median error : 6.65% / average error : 6.63% / maxhist error : 5.23% / mix error : 6.64%
# ----------------------------------------------------------------------------------------
# gh_3_slow_2 median_ distance(m) :  2.80035716538
# gh_3_slow_2 average_ distance(m) :  2.80105451465
# gh_3_slow_2 maxhist_ distance(m) :  2.84304320972
# gh_3_slow_2 mix_ distance(m) :  2.80070584001
# ----------------------------------------------------------------------------------------
# median error : 7.49% / average error : 7.75% / maxhist error : 6.08% / mix error : 7.62%
# ----------------------------------------------------------------------------------------
# gh_3_slow_3 median_ distance(m) :  2.77534505481
# gh_3_slow_3 average_ distance(m) :  2.76739803373
# gh_3_slow_3 maxhist_ distance(m) :  2.81764976291
# gh_3_slow_3 mix_ distance(m) :  2.77137154427
# ----------------------------------------------------------------------------------------
# median error : 8.31% / average error : 8.42% / maxhist error : 6.33% / mix error : 8.36%
# ----------------------------------------------------------------------------------------
# gh_3_stop_1 median_ distance(m) :  2.7508086529
# gh_3_stop_1 average_ distance(m) :  2.74733703061
# gh_3_stop_1 maxhist_ distance(m) :  2.8102239968
# gh_3_stop_1 mix_ distance(m) :  2.74907284176
# ----------------------------------------------------------------------------------------
# median error : 5.07% / average error : 5.10% / maxhist error : 4.17% / mix error : 5.09%
# ----------------------------------------------------------------------------------------
# gh_3_stop_2 median_ distance(m) :  2.84794319124
# gh_3_stop_2 average_ distance(m) :  2.8469466086
# gh_3_stop_2 maxhist_ distance(m) :  2.87494040461
# gh_3_stop_2 mix_ distance(m) :  2.84744489992
# ----------------------------------------------------------------------------------------
# median error : 4.33% / average error : 4.22% / maxhist error : 4.11% / mix error : 4.28%
# ----------------------------------------------------------------------------------------
# gh_3_stop_3 median_ distance(m) :  2.8699728803
# gh_3_stop_3 average_ distance(m) :  2.87347170031
# gh_3_stop_3 maxhist_ distance(m) :  2.87655542549
# gh_3_stop_3 mix_ distance(m) :  2.8717222903
# ----------------------------------------------------------------------------------------
# median error : 3.62% / average error : 2.90% / maxhist error : 8.71% / mix error : 3.26%
# ----------------------------------------------------------------------------------------
# dr_3_normal_1 median_ distance(m) :  2.89138068523
# dr_3_normal_1 average_ distance(m) :  2.91290022583
# dr_3_normal_1 maxhist_ distance(m) :  2.73878130694
# dr_3_normal_1 mix_ distance(m) :  2.90214045553
# ----------------------------------------------------------------------------------------
# median error : 4.72% / average error : 1.53% / maxhist error : 5.10% / mix error : 3.12%
# ----------------------------------------------------------------------------------------
# dr_3_normal_2 median_ distance(m) :  2.85834145829
# dr_3_normal_2 average_ distance(m) :  2.9542401075
# dr_3_normal_2 maxhist_ distance(m) :  2.84695667327
# dr_3_normal_2 mix_ distance(m) :  2.90629078289
# ----------------------------------------------------------------------------------------
# median error : 1.91% / average error : 0.05% / maxhist error : 4.73% / mix error : 0.98%
# ----------------------------------------------------------------------------------------
# dr_3_normal_3 median_ distance(m) :  2.94284561597
# dr_3_normal_3 average_ distance(m) :  2.99862615564
# dr_3_normal_3 maxhist_ distance(m) :  2.85824982051
# dr_3_normal_3 mix_ distance(m) :  2.97073588581
# ----------------------------------------------------------------------------------------
# median error : 3.36% / average error : 1.51% / maxhist error : 5.37% / mix error : 2.43%
# ----------------------------------------------------------------------------------------
# dr_3_fast_1 median_ distance(m) :  2.89922294756
# dr_3_fast_1 average_ distance(m) :  2.95481381693
# dr_3_fast_1 maxhist_ distance(m) :  2.83880852084
# dr_3_fast_1 mix_ distance(m) :  2.92701838224
# ----------------------------------------------------------------------------------------
# median error : 0.70% / average error : 1.31% / maxhist error : 5.87% / mix error : 0.30%
# ----------------------------------------------------------------------------------------
# dr_3_fast_2 median_ distance(m) :  2.9789447992
# dr_3_fast_2 average_ distance(m) :  3.03931782504
# dr_3_fast_2 maxhist_ distance(m) :  2.82380967996
# dr_3_fast_2 mix_ distance(m) :  3.00913131212
# ----------------------------------------------------------------------------------------
# median error : 2.40% / average error : 2.54% / maxhist error : 6.15% / mix error : 2.47%
# ----------------------------------------------------------------------------------------
# dr_3_fast_3 median_ distance(m) :  3.07195723794
# dr_3_fast_3 average_ distance(m) :  3.07611781258
# dr_3_fast_3 maxhist_ distance(m) :  2.81560652042
# dr_3_fast_3 mix_ distance(m) :  3.07403752526
# ----------------------------------------------------------------------------------------
# median error : 3.41% / average error : 4.92% / maxhist error : 1.97% / mix error : 4.17%
# ----------------------------------------------------------------------------------------
# dr_3_slow_1 median_ distance(m) :  3.10241761228
# dr_3_slow_1 average_ distance(m) :  3.14763432694
# dr_3_slow_1 maxhist_ distance(m) :  3.05920624449
# dr_3_slow_1 mix_ distance(m) :  3.12502596961
# ----------------------------------------------------------------------------------------
# median error : 1.28% / average error : 0.44% / maxhist error : 2.43% / mix error : 0.42%
# ----------------------------------------------------------------------------------------
# dr_3_slow_2 median_ distance(m) :  2.96150509116
# dr_3_slow_2 average_ distance(m) :  3.01331242878
# dr_3_slow_2 maxhist_ distance(m) :  2.9270200751
# dr_3_slow_2 mix_ distance(m) :  2.98740875997
# ----------------------------------------------------------------------------------------
# median error : 7.52% / average error : 8.97% / maxhist error : 8.06% / mix error : 8.24%
# ----------------------------------------------------------------------------------------
# dr_3_slow_3 median_ distance(m) :  3.22547258303
# dr_3_slow_3 average_ distance(m) :  3.26915089397
# dr_3_slow_3 maxhist_ distance(m) :  3.24184709722
# dr_3_slow_3 mix_ distance(m) :  3.2473117385
# ----------------------------------------------------------------------------------------
# median error : 2.83% / average error : 2.65% / maxhist error : 1.13% / mix error : 2.74%
# ----------------------------------------------------------------------------------------
# dr_3_stop_1 median_ distance(m) :  3.08495798227
# dr_3_stop_1 average_ distance(m) :  3.079530085
# dr_3_stop_1 maxhist_ distance(m) :  2.9661475678
# dr_3_stop_1 mix_ distance(m) :  3.08224403363
# ----------------------------------------------------------------------------------------
# median error : 5.41% / average error : 6.61% / maxhist error : 2.77% / mix error : 6.01%
# ----------------------------------------------------------------------------------------
# dr_3_stop_2 median_ distance(m) :  3.16243365701
# dr_3_stop_2 average_ distance(m) :  3.19841407678
# dr_3_stop_2 maxhist_ distance(m) :  3.08312665994
# dr_3_stop_2 mix_ distance(m) :  3.18042386689
# ----------------------------------------------------------------------------------------
# median error : 9.25% / average error : 11.53% / maxhist error : 3.89% / mix error : 10.39%
# ----------------------------------------------------------------------------------------
# dr_3_stop_3 median_ distance(m) :  3.2775717075
# dr_3_stop_3 average_ distance(m) :  3.34585698784
# dr_3_stop_3 maxhist_ distance(m) :  3.11666251163
# dr_3_stop_3 mix_ distance(m) :  3.31171434767
# ----------------------------------------------------------------------------------------
# median error : 1.81% / average error : 0.52% / maxhist error : 0.78% / mix error : 1.16%
# ----------------------------------------------------------------------------------------
# ss_10_normal_1 median_ distance(m) :  10.1807882342
# ss_10_normal_1 average_ distance(m) :  10.0517418719
# ss_10_normal_1 maxhist_ distance(m) :  9.92214162921
# ss_10_normal_1 mix_ distance(m) :  10.116265053
# ----------------------------------------------------------------------------------------
# median error : 1.92% / average error : 0.98% / maxhist error : 0.71% / mix error : 1.45%
# ----------------------------------------------------------------------------------------
# ss_10_normal_2 median_ distance(m) :  10.1917023337
# ss_10_normal_2 average_ distance(m) :  10.098492879
# ss_10_normal_2 maxhist_ distance(m) :  10.0705371346
# ss_10_normal_2 mix_ distance(m) :  10.1450976064
# ----------------------------------------------------------------------------------------
# median error : 1.89% / average error : 0.68% / maxhist error : 1.54% / mix error : 1.29%
# ----------------------------------------------------------------------------------------
# ss_10_normal_3 median_ distance(m) :  10.1889401168
# ss_10_normal_3 average_ distance(m) :  10.0680943256
# ss_10_normal_3 maxhist_ distance(m) :  10.1540437146
# ss_10_normal_3 mix_ distance(m) :  10.1285172212
# ----------------------------------------------------------------------------------------
# median error : 1.59% / average error : 0.09% / maxhist error : 2.92% / mix error : 0.84%
# ----------------------------------------------------------------------------------------
# ss_10_fast_1 median_ distance(m) :  10.1586254026
# ss_10_fast_1 average_ distance(m) :  10.0086257276
# ss_10_fast_1 maxhist_ distance(m) :  9.70752727628
# ss_10_fast_1 mix_ distance(m) :  10.0836255651
# ----------------------------------------------------------------------------------------
# median error : 1.35% / average error : 3.11% / maxhist error : 6.19% / mix error : 2.23%
# ----------------------------------------------------------------------------------------
# ss_10_fast_2 median_ distance(m) :  9.86540070942
# ss_10_fast_2 average_ distance(m) :  9.68876024311
# ss_10_fast_2 maxhist_ distance(m) :  9.38095240607
# ss_10_fast_2 mix_ distance(m) :  9.77708047627
# ----------------------------------------------------------------------------------------
# median error : 1.39% / average error : 3.43% / maxhist error : 4.50% / mix error : 2.41%
# ----------------------------------------------------------------------------------------
# ss_10_fast_3 median_ distance(m) :  9.86122036295
# ss_10_fast_3 average_ distance(m) :  9.65693942277
# ss_10_fast_3 maxhist_ distance(m) :  9.5500137997
# ss_10_fast_3 mix_ distance(m) :  9.75907989286
# ----------------------------------------------------------------------------------------
# median error : 1.81% / average error : 2.30% / maxhist error : 3.20% / mix error : 2.05%
# ----------------------------------------------------------------------------------------
# ss_10_slow_1 median_ distance(m) :  9.81880139589
# ss_10_slow_1 average_ distance(m) :  9.77024384065
# ss_10_slow_1 maxhist_ distance(m) :  9.68010840919
# ss_10_slow_1 mix_ distance(m) :  9.79452261827
# ----------------------------------------------------------------------------------------
# median error : 4.13% / average error : 4.91% / maxhist error : 4.23% / mix error : 4.52%
# ----------------------------------------------------------------------------------------
# ss_10_slow_2 median_ distance(m) :  9.58705013011
# ss_10_slow_2 average_ distance(m) :  9.50853973374
# ss_10_slow_2 maxhist_ distance(m) :  9.57736962324
# ss_10_slow_2 mix_ distance(m) :  9.54779493192
# ----------------------------------------------------------------------------------------
# median error : 3.45% / average error : 4.05% / maxhist error : 4.51% / mix error : 3.75%
# ----------------------------------------------------------------------------------------
# ss_10_slow_3 median_ distance(m) :  9.65505349888
# ss_10_slow_3 average_ distance(m) :  9.59455414456
# ss_10_slow_3 maxhist_ distance(m) :  9.5490524802
# ss_10_slow_3 mix_ distance(m) :  9.62480382172
# ----------------------------------------------------------------------------------------
# median error : 5.78% / average error : 7.05% / maxhist error : 6.47% / mix error : 6.42%
# ----------------------------------------------------------------------------------------
# ss_10_stop_1 median_ distance(m) :  9.42160245538
# ss_10_stop_1 average_ distance(m) :  9.29465993586
# ss_10_stop_1 maxhist_ distance(m) :  9.35318714454
# ss_10_stop_1 mix_ distance(m) :  9.35813119562
# ----------------------------------------------------------------------------------------
# median error : 6.11% / average error : 6.74% / maxhist error : 5.89% / mix error : 6.42%
# ----------------------------------------------------------------------------------------
# ss_10_stop_2 median_ distance(m) :  9.38924565521
# ss_10_stop_2 average_ distance(m) :  9.32584427069
# ss_10_stop_2 maxhist_ distance(m) :  9.41079465329
# ss_10_stop_2 mix_ distance(m) :  9.35754496295
# ----------------------------------------------------------------------------------------
# median error : 5.68% / average error : 6.52% / maxhist error : 5.63% / mix error : 6.10%
# ----------------------------------------------------------------------------------------
# ss_10_stop_3 median_ distance(m) :  9.43156673394
# ss_10_stop_3 average_ distance(m) :  9.34825025666
# ss_10_stop_3 maxhist_ distance(m) :  9.43709333109
# ss_10_stop_3 mix_ distance(m) :  9.3899084953
# ----------------------------------------------------------------------------------------
# median error : 0.18% / average error : 0.43% / maxhist error : 1.42% / mix error : 0.31%
# ----------------------------------------------------------------------------------------
# yg_10_normal_1 median_ distance(m) :  9.98197803895
# yg_10_normal_1 average_ distance(m) :  9.95656563931
# yg_10_normal_1 maxhist_ distance(m) :  9.85758452006
# yg_10_normal_1 mix_ distance(m) :  9.96927183913
# ----------------------------------------------------------------------------------------
# median error : 0.91% / average error : 0.69% / maxhist error : 1.42% / mix error : 0.80%
# ----------------------------------------------------------------------------------------
# yg_10_normal_2 median_ distance(m) :  10.0907368683
# yg_10_normal_2 average_ distance(m) :  10.0688057638
# yg_10_normal_2 maxhist_ distance(m) :  9.85761169499
# yg_10_normal_2 mix_ distance(m) :  10.079771316
# ----------------------------------------------------------------------------------------
# median error : 0.84% / average error : 0.01% / maxhist error : 0.63% / mix error : 0.42%
# ----------------------------------------------------------------------------------------
# yg_10_normal_3 median_ distance(m) :  10.0836257758
# yg_10_normal_3 average_ distance(m) :  10.0006812905
# yg_10_normal_3 maxhist_ distance(m) :  9.93710197413
# yg_10_normal_3 mix_ distance(m) :  10.0421535331
# ----------------------------------------------------------------------------------------
# median error : 0.62% / average error : 1.35% / maxhist error : 1.78% / mix error : 0.37%
# ----------------------------------------------------------------------------------------
# yg_10_fast_1 median_ distance(m) :  10.0618576986
# yg_10_fast_1 average_ distance(m) :  9.86485767447
# yg_10_fast_1 maxhist_ distance(m) :  9.822427657
# yg_10_fast_1 mix_ distance(m) :  9.96335768653
# ----------------------------------------------------------------------------------------
# median error : 3.86% / average error : 2.40% / maxhist error : 2.76% / mix error : 3.13%
# ----------------------------------------------------------------------------------------
# yg_10_fast_2 median_ distance(m) :  10.3856579022
# yg_10_fast_2 average_ distance(m) :  10.2397213027
# yg_10_fast_2 maxhist_ distance(m) :  10.2761178406
# yg_10_fast_2 mix_ distance(m) :  10.3126896024
# ----------------------------------------------------------------------------------------
# median error : 0.24% / average error : 1.95% / maxhist error : 1.96% / mix error : 0.85%
# ----------------------------------------------------------------------------------------
# yg_10_fast_3 median_ distance(m) :  10.023628294
# yg_10_fast_3 average_ distance(m) :  9.80537487936
# yg_10_fast_3 maxhist_ distance(m) :  9.80383121674
# yg_10_fast_3 mix_ distance(m) :  9.9145015867
# ----------------------------------------------------------------------------------------
# median error : 1.36% / average error : 2.12% / maxhist error : 0.83% / mix error : 1.74%
# ----------------------------------------------------------------------------------------
# yg_10_slow_1 median_ distance(m) :  10.136246042
# yg_10_slow_1 average_ distance(m) :  10.2115650671
# yg_10_slow_1 maxhist_ distance(m) :  10.0832090878
# yg_10_slow_1 mix_ distance(m) :  10.1739055545
# ----------------------------------------------------------------------------------------
# median error : 0.72% / average error : 1.33% / maxhist error : 0.54% / mix error : 1.03%
# ----------------------------------------------------------------------------------------
# yg_10_slow_2 median_ distance(m) :  10.0723258399
# yg_10_slow_2 average_ distance(m) :  10.133456986
# yg_10_slow_2 maxhist_ distance(m) :  9.9461084057
# yg_10_slow_2 mix_ distance(m) :  10.102891413
# ----------------------------------------------------------------------------------------
# median error : 1.28% / average error : 2.37% / maxhist error : 0.33% / mix error : 1.83%
# ----------------------------------------------------------------------------------------
# yg_10_slow_3 median_ distance(m) :  10.1284142108
# yg_10_slow_3 average_ distance(m) :  10.237297524
# yg_10_slow_3 maxhist_ distance(m) :  10.0331056442
# yg_10_slow_3 mix_ distance(m) :  10.1828558674
# ----------------------------------------------------------------------------------------
# median error : 0.94% / average error : 1.75% / maxhist error : 0.79% / mix error : 1.35%
# ----------------------------------------------------------------------------------------
# yg_10_stop_1 median_ distance(m) :  10.0941679515
# yg_10_stop_1 average_ distance(m) :  10.1753609377
# yg_10_stop_1 maxhist_ distance(m) :  9.92079742941
# yg_10_stop_1 mix_ distance(m) :  10.1347644446
# ----------------------------------------------------------------------------------------
# median error : 1.04% / average error : 0.39% / maxhist error : 3.06% / mix error : 0.72%
# ----------------------------------------------------------------------------------------
# yg_10_stop_2 median_ distance(m) :  9.89558950098
# yg_10_stop_2 average_ distance(m) :  9.96120544526
# yg_10_stop_2 maxhist_ distance(m) :  9.69365834782
# yg_10_stop_2 mix_ distance(m) :  9.92839747312
# ----------------------------------------------------------------------------------------
# median error : 1.37% / average error : 0.83% / maxhist error : 0.50% / mix error : 1.10%
# ----------------------------------------------------------------------------------------
# yg_10_stop_3 median_ distance(m) :  10.1374856036
# yg_10_stop_3 average_ distance(m) :  10.0830316894
# yg_10_stop_3 maxhist_ distance(m) :  10.0497896343
# yg_10_stop_3 mix_ distance(m) :  10.1102586465
# ----------------------------------------------------------------------------------------
# median error : 0.03% / average error : 0.17% / maxhist error : 0.14% / mix error : 0.10%
# ----------------------------------------------------------------------------------------
# gh_10_normal_1 median_ distance(m) :  9.99687078942
# gh_10_normal_1 average_ distance(m) :  9.98336268645
# gh_10_normal_1 maxhist_ distance(m) :  9.98634742196
# gh_10_normal_1 mix_ distance(m) :  9.99011673794
# ----------------------------------------------------------------------------------------
# median error : 0.76% / average error : 0.93% / maxhist error : 1.42% / mix error : 0.84%
# ----------------------------------------------------------------------------------------
# gh_10_normal_2 median_ distance(m) :  9.92415477549
# gh_10_normal_2 average_ distance(m) :  9.90727510716
# gh_10_normal_2 maxhist_ distance(m) :  9.8575199875
# gh_10_normal_2 mix_ distance(m) :  9.91571494132
# ----------------------------------------------------------------------------------------
# median error : 1.85% / average error : 1.94% / maxhist error : 2.36% / mix error : 1.89%
# ----------------------------------------------------------------------------------------
# gh_10_normal_3 median_ distance(m) :  9.81538893417
# gh_10_normal_3 average_ distance(m) :  9.80642975319
# gh_10_normal_3 maxhist_ distance(m) :  9.76360307573
# gh_10_normal_3 mix_ distance(m) :  9.81090934368
# ----------------------------------------------------------------------------------------
# median error : 1.81% / average error : 2.12% / maxhist error : 3.21% / mix error : 1.96%
# ----------------------------------------------------------------------------------------
# gh_10_fast_1 median_ distance(m) :  9.81873148029
# gh_10_fast_1 average_ distance(m) :  9.78827901141
# gh_10_fast_1 maxhist_ distance(m) :  9.67896397131
# gh_10_fast_1 mix_ distance(m) :  9.80350524585
# ----------------------------------------------------------------------------------------
# median error : 0.81% / average error : 0.93% / maxhist error : 1.75% / mix error : 0.87%
# ----------------------------------------------------------------------------------------
# gh_10_fast_2 median_ distance(m) :  9.91942478733
# gh_10_fast_2 average_ distance(m) :  9.90729620175
# gh_10_fast_2 maxhist_ distance(m) :  9.82450872464
# gh_10_fast_2 mix_ distance(m) :  9.91336049454
# ----------------------------------------------------------------------------------------
# median error : 1.25% / average error : 1.43% / maxhist error : 2.17% / mix error : 1.34%
# ----------------------------------------------------------------------------------------
# gh_10_fast_3 median_ distance(m) :  9.87496005425
# gh_10_fast_3 average_ distance(m) :  9.85671733067
# gh_10_fast_3 maxhist_ distance(m) :  9.78255538399
# gh_10_fast_3 mix_ distance(m) :  9.86583869246
# ----------------------------------------------------------------------------------------
# median error : 0.59% / average error : 0.45% / maxhist error : 0.37% / mix error : 0.52%
# ----------------------------------------------------------------------------------------
# gh_10_slow_1 median_ distance(m) :  10.0589874759
# gh_10_slow_1 average_ distance(m) :  10.0451967701
# gh_10_slow_1 maxhist_ distance(m) :  10.0367744079
# gh_10_slow_1 mix_ distance(m) :  10.052092123
# ----------------------------------------------------------------------------------------
# median error : 0.72% / average error : 0.81% / maxhist error : 1.16% / mix error : 0.76%
# ----------------------------------------------------------------------------------------
# gh_10_slow_2 median_ distance(m) :  9.92849509224
# gh_10_slow_2 average_ distance(m) :  9.91870457931
# gh_10_slow_2 maxhist_ distance(m) :  9.8839970713
# gh_10_slow_2 mix_ distance(m) :  9.92359983577
# ----------------------------------------------------------------------------------------
# median error : 0.13% / average error : 0.38% / maxhist error : 0.06% / mix error : 0.25%
# ----------------------------------------------------------------------------------------
# gh_10_slow_3 median_ distance(m) :  9.98705573317
# gh_10_slow_3 average_ distance(m) :  9.96198169114
# gh_10_slow_3 maxhist_ distance(m) :  10.0060548081
# gh_10_slow_3 mix_ distance(m) :  9.97451871215
# ----------------------------------------------------------------------------------------
# median error : 1.42% / average error : 1.62% / maxhist error : 1.19% / mix error : 1.52%
# ----------------------------------------------------------------------------------------
# gh_10_stop_1 median_ distance(m) :  9.85767177124
# gh_10_stop_1 average_ distance(m) :  9.837818449
# gh_10_stop_1 maxhist_ distance(m) :  9.88118207981
# gh_10_stop_1 mix_ distance(m) :  9.84774511012
# ----------------------------------------------------------------------------------------
# median error : 1.68% / average error : 1.46% / maxhist error : 1.41% / mix error : 1.57%
# ----------------------------------------------------------------------------------------
# gh_10_stop_2 median_ distance(m) :  9.83189706049
# gh_10_stop_2 average_ distance(m) :  9.8539015284
# gh_10_stop_2 maxhist_ distance(m) :  9.85933410223
# gh_10_stop_2 mix_ distance(m) :  9.84289929445
# ----------------------------------------------------------------------------------------
# median error : 1.26% / average error : 1.46% / maxhist error : 1.31% / mix error : 1.36%
# ----------------------------------------------------------------------------------------
# gh_10_stop_3 median_ distance(m) :  9.87440389984
# gh_10_stop_3 average_ distance(m) :  9.85400953742
# gh_10_stop_3 maxhist_ distance(m) :  9.86938129647
# gh_10_stop_3 mix_ distance(m) :  9.86420671863
# ----------------------------------------------------------------------------------------
# median error : 7.06% / average error : 7.11% / maxhist error : 5.55% / mix error : 7.08%
# ----------------------------------------------------------------------------------------
# dr_10_normal_1 median_ distance(m) :  10.7055266078
# dr_10_normal_1 average_ distance(m) :  10.7108299668
# dr_10_normal_1 maxhist_ distance(m) :  10.5553075911
# dr_10_normal_1 mix_ distance(m) :  10.7081782873
# ----------------------------------------------------------------------------------------
# median error : 6.04% / average error : 5.98% / maxhist error : 4.97% / mix error : 6.01%
# ----------------------------------------------------------------------------------------
# dr_10_normal_2 median_ distance(m) :  10.6043475335
# dr_10_normal_2 average_ distance(m) :  10.5980962718
# dr_10_normal_2 maxhist_ distance(m) :  10.4972295219
# dr_10_normal_2 mix_ distance(m) :  10.6012219026
# ----------------------------------------------------------------------------------------
# median error : 4.46% / average error : 4.28% / maxhist error : 2.13% / mix error : 4.37%
# ----------------------------------------------------------------------------------------
# dr_10_normal_3 median_ distance(m) :  10.4459457161
# dr_10_normal_3 average_ distance(m) :  10.4275529975
# dr_10_normal_3 maxhist_ distance(m) :  10.2133861577
# dr_10_normal_3 mix_ distance(m) :  10.4367493568
# ----------------------------------------------------------------------------------------
# median error : 2.61% / average error : 1.95% / maxhist error : 0.50% / mix error : 2.28%
# ----------------------------------------------------------------------------------------
# dr_10_fast_1 median_ distance(m) :  10.2609496138
# dr_10_fast_1 average_ distance(m) :  10.1945393808
# dr_10_fast_1 maxhist_ distance(m) :  9.94960914808
# dr_10_fast_1 mix_ distance(m) :  10.2277444973
# ----------------------------------------------------------------------------------------
# median error : 2.06% / average error : 1.41% / maxhist error : 2.00% / mix error : 1.73%
# ----------------------------------------------------------------------------------------
# dr_10_fast_2 median_ distance(m) :  10.2063687853
# dr_10_fast_2 average_ distance(m) :  10.1405093645
# dr_10_fast_2 maxhist_ distance(m) :  9.79989804781
# dr_10_fast_2 mix_ distance(m) :  10.1734390749
# ----------------------------------------------------------------------------------------
# median error : 4.92% / average error : 4.94% / maxhist error : 2.47% / mix error : 4.93%
# ----------------------------------------------------------------------------------------
# dr_10_fast_3 median_ distance(m) :  10.4921995881
# dr_10_fast_3 average_ distance(m) :  10.4937002894
# dr_10_fast_3 maxhist_ distance(m) :  10.2469705288
# dr_10_fast_3 mix_ distance(m) :  10.4929499388
# ----------------------------------------------------------------------------------------
# median error : 2.61% / average error : 3.18% / maxhist error : 1.52% / mix error : 2.89%
# ----------------------------------------------------------------------------------------
# dr_10_slow_1 median_ distance(m) :  10.2606942348
# dr_10_slow_1 average_ distance(m) :  10.3181567902
# dr_10_slow_1 maxhist_ distance(m) :  10.1516797096
# dr_10_slow_1 mix_ distance(m) :  10.2894255125
# ----------------------------------------------------------------------------------------
# median error : 1.93% / average error : 2.34% / maxhist error : 0.69% / mix error : 2.13%
# ----------------------------------------------------------------------------------------
# dr_10_slow_2 median_ distance(m) :  10.1925191626
# dr_10_slow_2 average_ distance(m) :  10.2342708769
# dr_10_slow_2 maxhist_ distance(m) :  10.0691611432
# dr_10_slow_2 mix_ distance(m) :  10.2133950197
# ----------------------------------------------------------------------------------------
# median error : 1.67% / average error : 2.03% / maxhist error : 0.24% / mix error : 1.85%
# ----------------------------------------------------------------------------------------
# dr_10_slow_3 median_ distance(m) :  10.1665594861
# dr_10_slow_3 average_ distance(m) :  10.2032737352
# dr_10_slow_3 maxhist_ distance(m) :  10.0235769193
# dr_10_slow_3 mix_ distance(m) :  10.1849166106
# ----------------------------------------------------------------------------------------
# median error : 1.59% / average error : 1.53% / maxhist error : 2.33% / mix error : 1.56%
# ----------------------------------------------------------------------------------------
# dr_10_stop_1 median_ distance(m) :  9.84147531744
# dr_10_stop_1 average_ distance(m) :  9.84711420096
# dr_10_stop_1 maxhist_ distance(m) :  9.76675864559
# dr_10_stop_1 mix_ distance(m) :  9.8442947592
# ----------------------------------------------------------------------------------------
# median error : 1.54% / average error : 1.27% / maxhist error : 4.27% / mix error : 1.41%
# ----------------------------------------------------------------------------------------
# dr_10_stop_2 median_ distance(m) :  9.84599132922
# dr_10_stop_2 average_ distance(m) :  9.87278587381
# dr_10_stop_2 maxhist_ distance(m) :  9.57291412879
# dr_10_stop_2 mix_ distance(m) :  9.85938860151
# ----------------------------------------------------------------------------------------
# median error : 0.97% / average error : 1.54% / maxhist error : 2.54% / mix error : 1.26%
# ----------------------------------------------------------------------------------------
# dr_10_stop_3 median_ distance(m) :  10.0973901439
# dr_10_stop_3 average_ distance(m) :  10.1540623157
# dr_10_stop_3 maxhist_ distance(m) :  9.7462648462
# dr_10_stop_3 mix_ distance(m) :  10.1257262298
# ----------------------------------------------------------------------------------------
# "\nmedian , average , maxhist = distcalc('ss_3_normal_1')\nmedian , average , maxhist = distcalc('ss_3_normal_2')\nmedian , average , maxhist = distcalc('ss_3_normal_3')\nmedian , average , maxhist = distcalc('ss_3_fast_1')\nmedian , average , maxhist = distcalc('ss_3_fast_2')\nmedian , average , maxhist = distcalc('ss_3_fast_3')\nmedian , average , maxhist = distcalc('ss_3_slow_1')\nmedian , average , maxhist = distcalc('ss_3_slow_2')\nmedian , average , maxhist = distcalc('ss_3_slow_3')\nmedian , average , maxhist = distcalc('ss_3_stop_1')\nmedian , average , maxhist = distcalc('ss_3_stop_2')\nmedian , average , maxhist = distcalc('ss_3_stop_3')\nmedian , average , maxhist = distcalc('ss_10_normal_1')\nmedian , average , maxhist = distcalc('ss_10_normal_2')\nmedian , average , maxhist = distcalc('ss_10_normal_3')\nmedian , average , maxhist = distcalc('ss_10_fast_1')\nmedian , average , maxhist = distcalc('ss_10_fast_2')\nmedian , average , maxhist = distcalc('ss_10_fast_3')\nmedian , average , maxhist = distcalc('ss_10_slow_1')\nmedian , average , maxhist = distcalc('ss_10_slow_2')\nmedian , average , maxhist = distcalc('ss_10_slow_3')\nmedian , average , maxhist = distcalc('ss_10_stop_1')\nmedian , average , maxhist = distcalc('ss_10_stop_2')\nmedian , average , maxhist = distcalc('ss_10_stop_3')\nmedian , average , maxhist = distcalc('yg_3_normal_1')\nmedian , average , maxhist = distcalc('yg_3_normal_2')\nmedian , average , maxhist = distcalc('yg_3_normal_3')\nmedian , average , maxhist = distcalc('yg_3_fast_1')\n#median , average , maxhist = distcalc('yg_3_fast_2')\n#median , average , maxhist = distcalc('yg_3_fast_3')\nmedian , average , maxhist = distcalc('yg_3_slow_1')\nmedian , average , maxhist = distcalc('yg_3_slow_2')\nmedian , average , maxhist = distcalc('yg_3_slow_3')\nmedian , average , maxhist = distcalc('yg_3_stop_1')\nmedian , average , maxhist = distcalc('yg_3_stop_2')\nmedian , average , maxhist = distcalc('yg_3_stop_3')\nmedian , average , maxhist = distcalc('yg_10_normal_1')\nmedian , average , maxhist = distcalc('yg_10_normal_2')\nmedian , average , maxhist = distcalc('yg_10_normal_3')\nmedian , average , maxhist = distcalc('yg_10_fast_1')\nmedian , average , maxhist = distcalc('yg_10_fast_2')\nmedian , average , maxhist = distcalc('yg_10_fast_3')\nmedian , average , maxhist = distcalc('yg_10_slow_1')\nmedian , average , maxhist = distcalc('yg_10_slow_2')\nmedian , average , maxhist = distcalc('yg_10_slow_3')\nmedian , average , maxhist = distcalc('yg_10_stop_1')\nmedian , average , maxhist = distcalc('yg_10_stop_2')\nmedian , average , maxhist = distcalc('yg_10_stop_3')\n"
